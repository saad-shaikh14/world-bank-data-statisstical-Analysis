# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab 
from scipy.stats import norm
import seaborn as sns

# %% [markdown]
# # Reading Files

# %%
ADS2 = pd.read_excel('ELECTRICITY URBAN.xlsx')
ADS2
# Out:
#     Years      Aruba  Africa Eastern and Southern  Afghanistan  \
# 0    1990        NaN                          NaN          NaN
# 1    1991        NaN                          NaN          NaN
# 2    1992        NaN                          NaN          NaN
# 3    1993        NaN                          NaN    31.693097
# 4    1994        NaN                          NaN    32.714738
# 5    1995        NaN                          NaN    33.703684
# 6    1996        NaN                          NaN    32.748158
# 7    1997        NaN                          NaN    32.552540
# 8    1998        NaN                          NaN    33.542690
# 9    1999        NaN                          NaN    34.899477
# 10   2000  20.086007                          NaN    34.658011
# 11   2001  23.103178                          NaN    35.664311
# 12   2002  24.223430                          NaN    36.403550
# 13   2003  25.023184                          NaN    40.673975
# ...

# %%
ADS2_1 = pd.read_excel('OIL2.xlsx',index_col=None)
ADS2_1
# Out:
#     Years     Aruba  Africa Eastern and Southern  Afghanistan  \
# 0    1990  0.857834                          NaN    11.865386
# 1    1991  0.862841                          NaN    10.623388
# 2    1992  0.866045                          NaN    12.516328
# 3    1993  0.894157                          NaN    12.868154
# 4    1994  1.134869                          NaN    12.176712
# 5    1995  1.349312                          NaN    14.685734
# 6    1996  1.189779                          NaN    13.268470
# 7    1997  1.486807                          NaN     4.977801
# 8    1998  1.284391                          NaN     6.313727
# 9    1999  1.767648                          NaN     5.288195
# 10   2000  2.016128                          NaN     5.125976
# 11   2001  1.780298                          NaN     5.377575
# 12   2002  1.599738                          NaN     4.482319
# 13   2003  1.681160                          NaN     4.827787
# ...

# %% [markdown]
# # Handling Na Values

# %%
a = ADS2.fillna(0)
a
# Out:
#     Years      Aruba  Africa Eastern and Southern  Afghanistan  \
# 0    1990   0.000000                     0.000000     0.000000
# 1    1991   0.000000                     0.000000     0.000000
# 2    1992   0.000000                     0.000000     0.000000
# 3    1993   0.000000                     0.000000    31.693097
# 4    1994   0.000000                     0.000000    32.714738
# 5    1995   0.000000                     0.000000    33.703684
# 6    1996   0.000000                     0.000000    32.748158
# 7    1997   0.000000                     0.000000    32.552540
# 8    1998   0.000000                     0.000000    33.542690
# 9    1999   0.000000                     0.000000    34.899477
# 10   2000  20.086007                     0.000000    34.658011
# 11   2001  23.103178                     0.000000    35.664311
# 12   2002  24.223430                     0.000000    36.403550
# 13   2003  25.023184                     0.000000    40.673975
# ...

# %%
b = ADS2_1.fillna(0)
b
# Out:
#     Years     Aruba  Africa Eastern and Southern  Afghanistan  \
# 0    1990  0.857834                          0.0    11.865386
# 1    1991  0.862841                          0.0    10.623388
# 2    1992  0.866045                          0.0    12.516328
# 3    1993  0.894157                          0.0    12.868154
# 4    1994  1.134869                          0.0    12.176712
# 5    1995  1.349312                          0.0    14.685734
# 6    1996  1.189779                          0.0    13.268470
# 7    1997  1.486807                          0.0     4.977801
# 8    1998  1.284391                          0.0     6.313727
# 9    1999  1.767648                          0.0     5.288195
# 10   2000  2.016128                          0.0     5.125976
# 11   2001  1.780298                          0.0     5.377575
# 12   2002  1.599738                          0.0     4.482319
# 13   2003  1.681160                          0.0     4.827787
# ...

# %%
a.describe()
# Out:
#              Years  Country Name      Aruba  Africa Eastern and Southern  \
# count    30.000000     30.000000  30.000000                    30.000000
# mean   2004.500000     99.420246  20.134427                    31.634603
# std       8.803408      1.907725  15.406162                    37.605707
# min    1990.000000     91.660398   0.000000                     0.000000
# 25%    1997.250000    100.000000   0.000000                     0.000000
# 50%    2004.500000    100.000000  25.599760                    11.147635
# 75%    2011.750000    100.000000  30.696118                    63.117376
# max    2019.000000    100.000000  43.640661                    98.715622
#
#        Afghanistan  Africa Western and Central      Angola  Albania  \
# count    30.000000                   30.000000   30.000000     30.0
# mean     36.494923                   22.233742   99.987000    100.0
# std      13.782417                   18.056029    0.033234      0.0
# ...

# %%
b.describe()
# Out:
#              Years  Country Name      Aruba  Africa Eastern and Southern  \
# count    30.000000     30.000000  30.000000                    30.000000
# mean   2004.500000     99.420246  20.134427                    31.634603
# std       8.803408      1.907725  15.406162                    37.605707
# min    1990.000000     91.660398   0.000000                     0.000000
# 25%    1997.250000    100.000000   0.000000                     0.000000
# 50%    2004.500000    100.000000  25.599760                    11.147635
# 75%    2011.750000    100.000000  30.696118                    63.117376
# max    2019.000000    100.000000  43.640661                    98.715622
#
#        Afghanistan  Africa Western and Central      Angola  Albania  \
# count    30.000000                   30.000000   30.000000     30.0
# mean     36.494923                   22.233742   99.987000    100.0
# std      13.782417                   18.056029    0.033234      0.0
# ...

# %% [markdown]
# # Statistical summary on Nigeria Indicator Urban [Access to electricity (% of population)]

# %%
v = a.Nigeria.astype(int).describe()
v
# Out:
# count    30.000000
# mean     68.666667
# std      23.889593
# min       0.000000
# 25%      71.250000
# 50%      74.000000
# 75%      78.750000
# max      88.000000
# Name: Nigeria, dtype: float64

# %% [markdown]
# # plotting Descriptive Statistics for Nigera

# %%
v.plot(kind="bar", xlabel="Descriptive Statistics",ylabel = "Access to Electricity(% of total)",  title="Nigeria", colormap='Paired')
plt.xticks(rotation=30, horizontalalignment="center")
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'count'),
#   Text(1, 0, 'mean'),
#   Text(2, 0, 'std'),
#   Text(3, 0, 'min'),
#   Text(4, 0, '25%'),
#   Text(5, 0, '50%'),
#   Text(6, 0, '75%'),
#   Text(7, 0, 'max')])

# %% [markdown]
# # Statistical summary on Singapore Indicator Urban [Access to electricity (% of population)]

# %%
u = a.Singapore.astype(int).describe()
u
# Out:
# count    30.000000
# mean     22.600000
# std      23.272894
# min       0.000000
# 25%       0.000000
# 50%      14.500000
# 75%      41.000000
# max      70.000000
# Name: Singapore, dtype: float64

# %% [markdown]
# # plotting Descriptive Statistics for Singapore

# %%
u.plot(kind="bar", xlabel="Descriptive Statistics",ylabel = "Access to Electricity(% of total)",  title="Singapore", color=['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8'])
plt.xticks(rotation=30, horizontalalignment="center")
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'count'),
#   Text(1, 0, 'mean'),
#   Text(2, 0, 'std'),
#   Text(3, 0, 'min'),
#   Text(4, 0, '25%'),
#   Text(5, 0, '50%'),
#   Text(6, 0, '75%'),
#   Text(7, 0, 'max')])

# %% [markdown]
# # Statistical summary on Japan Indicator Electricity production from oil sources (% of total)

# %%
p = b.Japan.astype(int).describe()
p
# Out:
# count    26.000000
# mean      4.115385
# std       3.063683
# min       0.000000
# 25%       1.000000
# 50%       4.000000
# 75%       7.000000
# max       9.000000
# Name: Japan, dtype: float64

# %% [markdown]
# # Plotting Descriptive Statistics for Japan

# %%
p.plot(kind="bar", xlabel="Descriptive Statistics",ylabel = "Elec prod from oil sources (% of total)",  title="Japan", color=['C11', 'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C29'])
plt.xticks(rotation=30, horizontalalignment="center")
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'count'),
#   Text(1, 0, 'mean'),
#   Text(2, 0, 'std'),
#   Text(3, 0, 'min'),
#   Text(4, 0, '25%'),
#   Text(5, 0, '50%'),
#   Text(6, 0, '75%'),
#   Text(7, 0, 'max')])

# %% [markdown]
# # Statistical summary on China Indicator  Electricity production from oil sources (% of total)

# %%
q = b.China.astype(int).describe()
q
# Out:
# count    26.000000
# mean     11.192308
# std      16.759521
# min       0.000000
# 25%       0.000000
# 50%       3.000000
# 75%      10.500000
# max      50.000000
# Name: China, dtype: float64

# %% [markdown]
# # Plotting Descriptive Statistics for China

# %%
q.plot(kind="bar", xlabel="Descriptive Statistics",ylabel = "Elec prod from oil sources (% of total)",  title="China")
plt.xticks(rotation=30, horizontalalignment="center")
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'count'),
#   Text(1, 0, 'mean'),
#   Text(2, 0, 'std'),
#   Text(3, 0, 'min'),
#   Text(4, 0, '25%'),
#   Text(5, 0, '50%'),
#   Text(6, 0, '75%'),
#   Text(7, 0, 'max')])

# %% [markdown]
# # Task 2

# %%
a.plot(x="Years", ylabel = "Access to electricity Urban (% of population)" , y=["Afghanistan","Algeria","Bolivia"],
        kind="line", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Years', ylabel='Access to electricity Urban (% of population)'>

# %%
b.plot(x="Years", ylabel = "Electricity production from oil sources (% of total)" , y=["Afghanistan","Algeria","Bolivia"],
        kind="line", figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Years', ylabel='Electricity production from oil sources (% of total)'>
